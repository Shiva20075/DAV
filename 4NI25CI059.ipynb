# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\User\Downloads\archive (4)\synthetic_dataset.csv")
print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4362 entries, 0 to 4361
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  1614 non-null   str
#  1   Price     4188 non-null   float64
#  2   Rating    2312 non-null   float64
#  3   Stock     3010 non-null   str
#  4   Discount  3970 non-null   float64
# dtypes: float64(3), str(2)
# memory usage: 202.5 KB
# None

# %%
print(data[["Price", "Discount"]].describe())
# Out:
#              Price     Discount
# count  4188.000000  3970.000000
# mean   5016.970630    24.516625
# std    2839.984813    14.347164
# min     102.000000     0.000000
# 25%    2628.250000    12.000000
# 50%    4996.500000    25.000000
# 75%    7418.000000    37.000000
# max    9999.000000    49.000000

# %%
print(data)
# Out:
#      Category   Price    Rating         Stock  Discount
# 0         NaN  5548.0  1.870322           NaN       0.0
# 1         NaN  3045.0  4.757798           NaN      38.0
# 2         NaN  4004.0       NaN      In Stock       0.0
# 3         NaN  4808.0  1.492085           NaN      33.0
# 4         NaN  1817.0       NaN  Out of Stock      23.0
# ...       ...     ...       ...           ...       ...
# 4357      NaN  4436.0  4.728335           NaN      49.0
# 4358        B  6236.0       NaN  Out of Stock       4.0
# 4359      NaN  3283.0       NaN  Out of Stock       9.0
# 4360        D  2999.0  4.425995           NaN      40.0
# 4361      NaN     NaN  2.184471           NaN       0.0
#
# [4362 rows x 5 columns]

# %%
data["Price"] = data["Price"].fillna(data["Price"].mean())
data["Discount"] = data["Discount"].fillna(data["Discount"].mean())

# %%
print(data[["Price", "Discount"]].isnull().sum())
# Out:
# Price       0
# Discount    0
# dtype: int64

# %%
data.head(10)
# Out:
#   Category   Price    Rating         Stock   Discount
# 0      NaN  5548.0  1.870322           NaN   0.000000
# 1      NaN  3045.0  4.757798           NaN  38.000000
# 2      NaN  4004.0       NaN      In Stock   0.000000
# 3      NaN  4808.0  1.492085           NaN  33.000000
# 4      NaN  1817.0       NaN  Out of Stock  23.000000
# 5      NaN  3522.0       NaN           NaN  24.516625
# 6        C   667.0  3.668341      In Stock  41.000000
# 7        A  7125.0  4.983998  Out of Stock   7.000000
# 8        A  2777.0  2.678384      In Stock   6.000000
# 9      NaN   463.0  4.626187           NaN   3.000000

# %%
data.isnull().sum()
# Out:
# Category    2748
# Price          0
# Rating      2050
# Stock       1352
# Discount       0
# dtype: int64

# %%
data["Rating"].describe()
# Out:
# count    2312.000000
# mean        3.038293
# std         1.143074
# min         1.000366
# 25%         2.069490
# 50%         3.082060
# 75%         4.008620
# max         4.997818
# Name: Rating, dtype: float64

# %%
data["Rating"] = data["Rating"].fillna(data["Rating"].median())

# %%
data["Rating"].describe()
# Out:
# count    4362.000000
# mean        3.058862
# std         0.832398
# min         1.000366
# 25%         2.949071
# 50%         3.082060
# 75%         3.180129
# max         4.997818
# Name: Rating, dtype: float64

# %%
data.isnull().sum()
# Out:
# Category    2748
# Price          0
# Rating         0
# Stock       1352
# Discount       0
# dtype: int64
